# %%
import pandas as pd
import numpy as np
import mne
import mne_bids
import q1k_init_tools as qit
import glob
import warnings
import os
import subprocess

# %%
rel_sourcedata_path = "../../sourcedata/"
rel_proj_root_path = "../../" 
site_code = "HSJ"
task_id_in = "PLR"
task_id_in_et = "PLR"
task_id_out = "PLR"
#subject_id = '002'
session_id = '01'
run_id = '1'

# %%
glob.glob(rel_sourcedata_path + "et/**/Q1K_HSJ_*_PLR.edf",recursive=True)
# Out:
# ['../../sourcedata/et/archive/Q1K_HSJ_100146_P/Q1K_HSJ_100146_P_PLR.edf',
#  '../../sourcedata/et/archive/Q1K_HSJ_100162_S1/Q1K_HSJ_100162_S1_PLR.edf',
#  '../../sourcedata/et/archive/Q1K_HSJ_1525-1006_M1/Q1K_HSJ_1525-1006_M1_PLR.edf',
#  '../../sourcedata/et/archive/Q1K_HSJ_100162_M1/Q1K_HSJ_100162_M1_PLR.edf',
#  '../../sourcedata/et/archive/Q1K_HSJ_1525_1037_F1/Q1K_HSJ_1525_1037_F1_PLR.edf',
#  '../../sourcedata/et/archive/Q1K_HSJ_1525-1026_M1/Q1K_HSJ_1525-1026_M1_PLR.edf',
#  '../../sourcedata/et/archive/Q1K_HSJ_1525-1024_M1/Q1K_HSJ_1525-1024_M1_PLR.edf',
#  '../../sourcedata/et/archive/Q1K_HSJ_10064_M1/Q1K_HSJ_10064_M1_PLR.edf',
#  '../../sourcedata/et/archive/Q1K_HSJ_100162_P/Q1K_HSJ_100162_P_PLR.edf',
#  '../../sourcedata/et/archive/Q1K_HSJ_1525-1024_P/Q1K_HSJ_1525-1024_P_PLR.edf']

# %%
for file in glob.glob(rel_sourcedata_path + "et/**/Q1K_HSJ_*_PLR.edf",recursive=True):
    print('Current data file: ' + file)
    # Select anything after the Q1K and before the AEP
    #subject_id = file.split('_')[2]
    site_part = file.split(site_code + "_")
    subject_number = site_part[1].split("_")[0]
    print('Participant number: ' + subject_number)
    subject_relation = site_part[1].split("_")[1].split("/")[0]
    print('Participant relation: ' + subject_relation)

    subject_id_in = subject_number + "_" + subject_relation
    print('Participant ID input: ' + subject_id_in)
    subject_id_out = subject_number.replace('_','').replace('-','') + subject_relation
    print('Participant ID output: ' + subject_id_out)
    
    #!edf2asc --input {file} {er_source_path + 'jnk.asc'}
    # Define the input and output file names
    in_name = file
    out_name = rel_sourcedata_path + "et/Q1K_" + site_code + "_" + subject_id_out + "_" + task_id_out + ".asc" #./output.asc"

    # Build the command to run
    command = "edf2asc -input " + in_name + " " + out_name
    print(command)

    # !{command}
# Out:
# Current data file: ../../sourcedata/et/archive/Q1K_HSJ_100146_P/Q1K_HSJ_100146_P_PLR.edf
# Participant number: 100146
# Participant relation: P
# Participant ID input: 100146_P
# Participant ID output: 100146P
# edf2asc --input ../../sourcedata/et/archive/Q1K_HSJ_100146_P/Q1K_HSJ_100146_P_PLR.edf ../../sourcedata/et/Q1K_HSJ_100146P_PLR.asc
#
# EDF2ASC: EyeLink EDF file -> ASCII (text) file translator
# EDF2ASC version 4.2.1197.0 Linux   standalone Sep 27 2024
# Copyright (c) 1996-2024 SR Research Ltd., last modified Sep 27 2024
#
# processing file ../../sourcedata/et/archive/Q1K_HSJ_100146_P/Q1K_HSJ_100146_P_PLR.edf
# loadEvents = 1
# Preamble of file ../../sourcedata/et/archive/Q1K_HSJ_100146_P/Q1K_HSJ_100146_P_PLR.edf
# | DATE: Fri May  3 11:05:10 2024                                              |
# | TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED                                   |
# | VERSION: EYELINK II 1                                                       |
# | SOURCE: EYELINK CL                                                          |
# | EYELINK II CL v5.50 Jun 16 2022 (EyeLink 1000 Plus)                         |
# | CAMERA: Eyelink GL Version 1.2 Sensor=AF7                                   |
# | SERIAL NUMBER: CLG-BIF38                                                    |
# | CAMERA_CONFIG: BIF38200.SCD                                                 |
# | RECORDED BY Q1K_ACAR_PLR_pfp_v1_01                                          |
# | SREB2.2.299 WIN32 LID:78E54DC8 Mod:2024.03.07 09:45 PST                     |
# ===============================================================================
#
# Converted successfully: 5116 events, 74589 samples, 2 blocks.
# Current data file: ../../sourcedata/et/archive/Q1K_HSJ_100162_S1/Q1K_HSJ_100162_S1_PLR.edf
# Participant number: 100162
# Participant relation: S1
# Participant ID input: 100162_S1
# Participant ID output: 100162S1
# edf2asc --input ../../sourcedata/et/archive/Q1K_HSJ_100162_S1/Q1K_HSJ_100162_S1_PLR.edf ../../sourcedata/et/Q1K_HSJ_100162S1_PLR.asc
#
# EDF2ASC: EyeLink EDF file -> ASCII (text) file translator
# EDF2ASC version 4.2.1197.0 Linux   standalone Sep 27 2024
# Copyright (c) 1996-2024 SR Research Ltd., last modified Sep 27 2024
#
# processing file ../../sourcedata/et/archive/Q1K_HSJ_100162_S1/Q1K_HSJ_100162_S1_PLR.edf
# loadEvents = 1
# Preamble of file ../../sourcedata/et/archive/Q1K_HSJ_100162_S1/Q1K_HSJ_100162_S1_PLR.edf
# | DATE: Thu May 30 11:06:48 2024                                              |
# | TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED                                   |
# | VERSION: EYELINK II 1                                                       |
# | SOURCE: EYELINK CL                                                          |
# | EYELINK II CL v5.50 Jun 16 2022 (EyeLink 1000 Plus)                         |
# | CAMERA: Eyelink GL Version 1.2 Sensor=AF7                                   |
# | SERIAL NUMBER: CLG-BIF38                                                    |
# | CAMERA_CONFIG: BIF38200.SCD                                                 |
# | RECORDED BY Q1K_ACAR_PLR_pfp_v1_01                                          |
# | SREB2.2.299 WIN32 LID:78E54DC8 Mod:2024.03.07 09:45 PST                     |
# ===============================================================================
#
# Converted successfully: 5272 events, 80696 samples, 2 blocks.
# Current data file: ../../sourcedata/et/archive/Q1K_HSJ_1525-1006_M1/Q1K_HSJ_1525-1006_M1_PLR.edf
# Participant number: 1525-1006
# Participant relation: M1
# Participant ID input: 1525-1006_M1
# Participant ID output: 15251006M1
# edf2asc --input ../../sourcedata/et/archive/Q1K_HSJ_1525-1006_M1/Q1K_HSJ_1525-1006_M1_PLR.edf ../../sourcedata/et/Q1K_HSJ_15251006M1_PLR.asc
#
# EDF2ASC: EyeLink EDF file -> ASCII (text) file translator
# EDF2ASC version 4.2.1197.0 Linux   standalone Sep 27 2024
# Copyright (c) 1996-2024 SR Research Ltd., last modified Sep 27 2024
#
# processing file ../../sourcedata/et/archive/Q1K_HSJ_1525-1006_M1/Q1K_HSJ_1525-1006_M1_PLR.edf
# loadEvents = 1
# Preamble of file ../../sourcedata/et/archive/Q1K_HSJ_1525-1006_M1/Q1K_HSJ_1525-1006_M1_PLR.edf
# | DATE: Thu May 23 10:31:46 2024                                              |
# | TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED                                   |
# | VERSION: EYELINK II 1                                                       |
# | SOURCE: EYELINK CL                                                          |
# | EYELINK II CL v5.50 Jun 16 2022 (EyeLink 1000 Plus)                         |
# | CAMERA: Eyelink GL Version 1.2 Sensor=AF7                                   |
# | SERIAL NUMBER: CLG-BIF38                                                    |
# | CAMERA_CONFIG: BIF38200.SCD                                                 |
# | RECORDED BY Q1K_ACAR_PLR_pfp_v1_01                                          |
# | SREB2.2.299 WIN32 LID:78E54DC8 Mod:2024.03.07 09:45 PST                     |
# ===============================================================================
#
# Converted successfully: 4183 events, 74264 samples, 2 blocks.
# Current data file: ../../sourcedata/et/archive/Q1K_HSJ_100162_M1/Q1K_HSJ_100162_M1_PLR.edf
# Participant number: 100162
# Participant relation: M1
# Participant ID input: 100162_M1
# Participant ID output: 100162M1
# edf2asc --input ../../sourcedata/et/archive/Q1K_HSJ_100162_M1/Q1K_HSJ_100162_M1_PLR.edf ../../sourcedata/et/Q1K_HSJ_100162M1_PLR.asc
#
# EDF2ASC: EyeLink EDF file -> ASCII (text) file translator
# EDF2ASC version 4.2.1197.0 Linux   standalone Sep 27 2024
# Copyright (c) 1996-2024 SR Research Ltd., last modified Sep 27 2024
#
# processing file ../../sourcedata/et/archive/Q1K_HSJ_100162_M1/Q1K_HSJ_100162_M1_PLR.edf
# loadEvents = 1
# Preamble of file ../../sourcedata/et/archive/Q1K_HSJ_100162_M1/Q1K_HSJ_100162_M1_PLR.edf
# | DATE: Thu May 30 14:00:38 2024                                              |
# | TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED                                   |
# | VERSION: EYELINK II 1                                                       |
# | SOURCE: EYELINK CL                                                          |
# | EYELINK II CL v5.50 Jun 16 2022 (EyeLink 1000 Plus)                         |
# | CAMERA: Eyelink GL Version 1.2 Sensor=AF7                                   |
# | SERIAL NUMBER: CLG-BIF38                                                    |
# | CAMERA_CONFIG: BIF38200.SCD                                                 |
# | RECORDED BY Q1K_ACAR_PLR_pfp_v1_01                                          |
# | SREB2.2.299 WIN32 LID:78E54DC8 Mod:2024.03.07 09:45 PST                     |
# ===============================================================================
#
# Converted successfully: 6097 events, 72945 samples, 2 blocks.
# Current data file: ../../sourcedata/et/archive/Q1K_HSJ_1525_1037_F1/Q1K_HSJ_1525_1037_F1_PLR.edf
# Participant number: 1525
# Participant relation: 1037
# Participant ID input: 1525_1037
# Participant ID output: 15251037
# edf2asc --input ../../sourcedata/et/archive/Q1K_HSJ_1525_1037_F1/Q1K_HSJ_1525_1037_F1_PLR.edf ../../sourcedata/et/Q1K_HSJ_15251037_PLR.asc
#
# EDF2ASC: EyeLink EDF file -> ASCII (text) file translator
# EDF2ASC version 4.2.1197.0 Linux   standalone Sep 27 2024
# Copyright (c) 1996-2024 SR Research Ltd., last modified Sep 27 2024
#
# processing file ../../sourcedata/et/archive/Q1K_HSJ_1525_1037_F1/Q1K_HSJ_1525_1037_F1_PLR.edf
# loadEvents = 1
# Preamble of file ../../sourcedata/et/archive/Q1K_HSJ_1525_1037_F1/Q1K_HSJ_1525_1037_F1_PLR.edf
# | DATE: Wed Jun 19 10:44:32 2024                                              |
# | TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED                                   |
# | VERSION: EYELINK II 1                                                       |
# | SOURCE: EYELINK CL                                                          |
# | EYELINK II CL v5.50 Jun 16 2022 (EyeLink 1000 Plus)                         |
# | CAMERA: Eyelink GL Version 1.2 Sensor=AF7                                   |
# | SERIAL NUMBER: CLG-BIF38                                                    |
# | CAMERA_CONFIG: BIF38200.SCD                                                 |
# | RECORDED BY Q1K_ACAR_PLR_pfp_v1_02                                          |
# | SREB2.2.299 WIN32 LID:78E54DC8 Mod:2024.06.14 15:22 PDT                     |
# ===============================================================================
#
# Converted successfully: 3536 events, 68384 samples, 2 blocks.
# Current data file: ../../sourcedata/et/archive/Q1K_HSJ_1525-1026_M1/Q1K_HSJ_1525-1026_M1_PLR.edf
# Participant number: 1525-1026
# Participant relation: M1
# Participant ID input: 1525-1026_M1
# Participant ID output: 15251026M1
# edf2asc --input ../../sourcedata/et/archive/Q1K_HSJ_1525-1026_M1/Q1K_HSJ_1525-1026_M1_PLR.edf ../../sourcedata/et/Q1K_HSJ_15251026M1_PLR.asc
#
# EDF2ASC: EyeLink EDF file -> ASCII (text) file translator
# EDF2ASC version 4.2.1197.0 Linux   standalone Sep 27 2024
# Copyright (c) 1996-2024 SR Research Ltd., last modified Sep 27 2024
#
# processing file ../../sourcedata/et/archive/Q1K_HSJ_1525-1026_M1/Q1K_HSJ_1525-1026_M1_PLR.edf
# loadEvents = 1
# Preamble of file ../../sourcedata/et/archive/Q1K_HSJ_1525-1026_M1/Q1K_HSJ_1525-1026_M1_PLR.edf
# | DATE: Thu Jun 13 12:16:19 2024                                              |
# | TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED                                   |
# | VERSION: EYELINK II 1                                                       |
# | SOURCE: EYELINK CL                                                          |
# | EYELINK II CL v5.50 Jun 16 2022 (EyeLink 1000 Plus)                         |
# | CAMERA: Eyelink GL Version 1.2 Sensor=AF7                                   |
# | SERIAL NUMBER: CLG-BIF38                                                    |
# | CAMERA_CONFIG: BIF38200.SCD                                                 |
# | RECORDED BY Q1K_ACAR_PLR_pfp_v1_01                                          |
# | SREB2.2.299 WIN32 LID:78E54DC8 Mod:2024.03.07 09:45 PST                     |
# ===============================================================================
#
# Converted successfully: 5950 events, 118755 samples, 2 blocks.
# Current data file: ../../sourcedata/et/archive/Q1K_HSJ_1525-1024_M1/Q1K_HSJ_1525-1024_M1_PLR.edf
# Participant number: 1525-1024
# Participant relation: M1
# Participant ID input: 1525-1024_M1
# Participant ID output: 15251024M1
# edf2asc --input ../../sourcedata/et/archive/Q1K_HSJ_1525-1024_M1/Q1K_HSJ_1525-1024_M1_PLR.edf ../../sourcedata/et/Q1K_HSJ_15251024M1_PLR.asc
#
# EDF2ASC: EyeLink EDF file -> ASCII (text) file translator
# EDF2ASC version 4.2.1197.0 Linux   standalone Sep 27 2024
# Copyright (c) 1996-2024 SR Research Ltd., last modified Sep 27 2024
#
# processing file ../../sourcedata/et/archive/Q1K_HSJ_1525-1024_M1/Q1K_HSJ_1525-1024_M1_PLR.edf
# loadEvents = 1
# Preamble of file ../../sourcedata/et/archive/Q1K_HSJ_1525-1024_M1/Q1K_HSJ_1525-1024_M1_PLR.edf
# | DATE: Tue Jun 25 14:45:30 2024                                              |
# | TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED                                   |
# | VERSION: EYELINK II 1                                                       |
# | SOURCE: EYELINK CL                                                          |
# | EYELINK II CL v5.50 Jun 16 2022 (EyeLink 1000 Plus)                         |
# | CAMERA: Eyelink GL Version 1.2 Sensor=AF7                                   |
# | SERIAL NUMBER: CLG-BIF38                                                    |
# | CAMERA_CONFIG: BIF38200.SCD                                                 |
# | RECORDED BY Q1K_ACAR_PLR_pfp_v1_02                                          |
# | SREB2.2.299 WIN32 LID:78E54DC8 Mod:2024.06.14 15:22 PDT                     |
# ===============================================================================
#
# Converted successfully: 2810 events, 52265 samples, 2 blocks.
# Current data file: ../../sourcedata/et/archive/Q1K_HSJ_10064_M1/Q1K_HSJ_10064_M1_PLR.edf
# Participant number: 10064
# Participant relation: M1
# Participant ID input: 10064_M1
# Participant ID output: 10064M1
# edf2asc --input ../../sourcedata/et/archive/Q1K_HSJ_10064_M1/Q1K_HSJ_10064_M1_PLR.edf ../../sourcedata/et/Q1K_HSJ_10064M1_PLR.asc
#
# EDF2ASC: EyeLink EDF file -> ASCII (text) file translator
# EDF2ASC version 4.2.1197.0 Linux   standalone Sep 27 2024
# Copyright (c) 1996-2024 SR Research Ltd., last modified Sep 27 2024
#
# processing file ../../sourcedata/et/archive/Q1K_HSJ_10064_M1/Q1K_HSJ_10064_M1_PLR.edf
# loadEvents = 1
# Preamble of file ../../sourcedata/et/archive/Q1K_HSJ_10064_M1/Q1K_HSJ_10064_M1_PLR.edf
# | DATE: Thu Jun 20 10:19:46 2024                                              |
# | TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED                                   |
# | VERSION: EYELINK II 1                                                       |
# | SOURCE: EYELINK CL                                                          |
# | EYELINK II CL v5.50 Jun 16 2022 (EyeLink 1000 Plus)                         |
# | CAMERA: Eyelink GL Version 1.2 Sensor=AF7                                   |
# | SERIAL NUMBER: CLG-BIF38                                                    |
# | CAMERA_CONFIG: BIF38200.SCD                                                 |
# | RECORDED BY Q1K_ACAR_PLR_pfp_v1_02                                          |
# | SREB2.2.299 WIN32 LID:78E54DC8 Mod:2024.06.14 15:22 PDT                     |
# ===============================================================================
#
# Converted successfully: 1031 events, 8126 samples, 1 blocks.
# Current data file: ../../sourcedata/et/archive/Q1K_HSJ_100162_P/Q1K_HSJ_100162_P_PLR.edf
# Participant number: 100162
# Participant relation: P
# Participant ID input: 100162_P
# Participant ID output: 100162P
# edf2asc --input ../../sourcedata/et/archive/Q1K_HSJ_100162_P/Q1K_HSJ_100162_P_PLR.edf ../../sourcedata/et/Q1K_HSJ_100162P_PLR.asc
#
# EDF2ASC: EyeLink EDF file -> ASCII (text) file translator
# EDF2ASC version 4.2.1197.0 Linux   standalone Sep 27 2024
# Copyright (c) 1996-2024 SR Research Ltd., last modified Sep 27 2024
#
# processing file ../../sourcedata/et/archive/Q1K_HSJ_100162_P/Q1K_HSJ_100162_P_PLR.edf
# loadEvents = 1
# Preamble of file ../../sourcedata/et/archive/Q1K_HSJ_100162_P/Q1K_HSJ_100162_P_PLR.edf
# | DATE: Thu May 30 12:27:41 2024                                              |
# | TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED                                   |
# | VERSION: EYELINK II 1                                                       |
# | SOURCE: EYELINK CL                                                          |
# | EYELINK II CL v5.50 Jun 16 2022 (EyeLink 1000 Plus)                         |
# | CAMERA: Eyelink GL Version 1.2 Sensor=AF7                                   |
# | SERIAL NUMBER: CLG-BIF38                                                    |
# | CAMERA_CONFIG: BIF38200.SCD                                                 |
# | RECORDED BY Q1K_ACAR_PLR_pfp_v1_01                                          |
# | SREB2.2.299 WIN32 LID:78E54DC8 Mod:2024.03.07 09:45 PST                     |
# ===============================================================================
#
# Converted successfully: 4569 events, 89539 samples, 2 blocks.
# Current data file: ../../sourcedata/et/archive/Q1K_HSJ_1525-1024_P/Q1K_HSJ_1525-1024_P_PLR.edf
# Participant number: 1525-1024
# Participant relation: P
# Participant ID input: 1525-1024_P
# Participant ID output: 15251024P
# edf2asc --input ../../sourcedata/et/archive/Q1K_HSJ_1525-1024_P/Q1K_HSJ_1525-1024_P_PLR.edf ../../sourcedata/et/Q1K_HSJ_15251024P_PLR.asc
#
# EDF2ASC: EyeLink EDF file -> ASCII (text) file translator
# EDF2ASC version 4.2.1197.0 Linux   standalone Sep 27 2024
# Copyright (c) 1996-2024 SR Research Ltd., last modified Sep 27 2024
#
# processing file ../../sourcedata/et/archive/Q1K_HSJ_1525-1024_P/Q1K_HSJ_1525-1024_P_PLR.edf
# loadEvents = 1
# Preamble of file ../../sourcedata/et/archive/Q1K_HSJ_1525-1024_P/Q1K_HSJ_1525-1024_P_PLR.edf
# | DATE: Tue Jun 25 13:32:47 2024                                              |
# | TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED                                   |
# | VERSION: EYELINK II 1                                                       |
# | SOURCE: EYELINK CL                                                          |
# | EYELINK II CL v5.50 Jun 16 2022 (EyeLink 1000 Plus)                         |
# | CAMERA: Eyelink GL Version 1.2 Sensor=AF7                                   |
# | SERIAL NUMBER: CLG-BIF38                                                    |
# | CAMERA_CONFIG: BIF38200.SCD                                                 |
# | RECORDED BY Q1K_ACAR_PLR_pfp_v1_02                                          |
# | SREB2.2.299 WIN32 LID:78E54DC8 Mod:2024.06.14 15:22 PDT                     |
# ===============================================================================
#
# Converted successfully: 3100 events, 54681 samples, 2 blocks.
